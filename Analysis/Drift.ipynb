# %% [markdown]
# <div style="font-family: 'Times New Roman', serif; text-align: center; padding: 20px 0;">
#
# <hr style="border: none; border-top: 1px solid #444;">
#
# <p style="font-size: 13px; letter-spacing: 3px; color: #666; margin: 15px 0 8px 0;">
# PATCH COMPOSITION
# </p>
#
# <p style="font-size: 32px; font-weight: bold; margin: 0 0 15px 0;">
# Alpha/Proton Drift
# </p>
#
# <hr style="border: none; border-top: 1px solid #444; width: 80%;">
#
# </div>

# %%
""" Import Modules """
import numpy             as np
import pandas            as pd
import speasy            as spz
import matplotlib.pyplot as plt

from matplotlib        import rcParams
from scipy.interpolate import interp1d
from scipy             import interpolate, stats
from datetime          import datetime, timedelta

# %%
""" Plot Config """
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 13
rcParams['axes.titlesize'] = 18
rcParams['axes.labelsize'] = 15
rcParams['xtick.labelsize'] = 13
rcParams['ytick.labelsize'] = 13
rcParams['legend.fontsize'] = 14
rcParams['figure.titlesize'] = 18

rcParams['axes.grid'] = True
rcParams['grid.alpha'] = 0.25
rcParams['grid.linestyle'] = '--'
rcParams['grid.linewidth'] = 0.5

# %% [markdown]
# <div style="
#     font-family: 'Times New Roman', serif;
#     margin: 35px 0 20px 0;
#     padding-bottom: 8px;
#     border-bottom: 1px solid #888;
# ">
#
# <p style="
#     font-size: 12px;
#     letter-spacing: 2.5px;
#     color: #666;
#     margin: 0 0 5px 0;
#     text-transform: uppercase;
# ">
# PATCH COMPOSITION - DRIFT
# </p>
#
# <p style="
#     font-size: 24px;
#     font-weight: bold;
#     margin: 0;
# ">
# Patch - Solar Orbiter
# </p>
#
# </div>

# %%
""" Time Config - solo """
start_solo = datetime(2022, 10, 21) 
stop_solo  = datetime(2022, 10, 29)

# %% [markdown]
# <div style="
#     font-family: 'Times New Roman', serif;
#     margin: 35px 0 20px 0;
#     padding-bottom: 8px;
#     border-bottom: 1px solid #888;
# ">
#
# <p style="
#     font-size: 12px;
#     letter-spacing: 2.5px;
#     color: #666;
#     margin: 0 0 5px 0;
#     text-transform: uppercase;
# ">
# PATCH COMPOSITION - DRIFT
# </p>
#
# <p style="
#     font-size: 24px;
#     font-weight: bold;
#     margin: 0;
# ">
# Patch - Parker Solar Orbiter
# </p>
#
# </div>

# %%
""" Time Config - psp """
start_psp = datetime(2022, 10, 21) 
stop_psp  = datetime(2022, 10, 29)

# %% [markdown]
# <div style="
#     font-family: 'Times New Roman', serif;
#     margin: 35px 0 20px 0;
#     padding-bottom: 8px;
#     border-bottom: 1px solid #888;
# ">
#
# <p style="
#     font-size: 12px;
#     letter-spacing: 2.5px;
#     color: #666;
#     margin: 0 0 5px 0;
#     text-transform: uppercase;
# ">
# PATCH COMPOSITION - DRIFT
# </p>
#
# <p style="
#     font-size: 24px;
#     font-weight: bold;
#     margin: 0;
# ">
# Radial Evolution
# </p>
#
# </div>

# %%
# Compute alpha/proton drift for all distances and then show it on heat map ? + Combine with amda data 
# Will need a good buffer and a cache cleaner
